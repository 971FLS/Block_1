# %% [markdown]
# ![Kayak](https://seekvectorlogo.com/wp-content/uploads/2018/01/kayak-vector-logo.png)
#
# # Plan your trip with Kayak
#
# ## Company's description 📇
#
# <a href="https://www.kayak.com" target="_blank">Kayak</a> is a travel search engine that helps user plan their next trip at the best price.
#
# The company was founded in 2004 by Steve Hafner & Paul M. English. After a few rounds of fundraising, Kayak was acquired by <a href="https://www.bookingholdings.com/" target="_blank">Booking Holdings</a> which now holds:
#
# * <a href="https://booking.com/" target="_blank">Booking.com</a>
# * <a href="https://kayak.com/" target="_blank">Kayak</a>
# * <a href="https://www.priceline.com/" target="_blank">Priceline</a>
# * <a href="https://www.agoda.com/" target="_blank">Agoda</a>
# * <a href="https://Rentalcars.com/" target="_blank">RentalCars</a>
# * <a href="https://www.opentable.com/" target="_blank">OpenTable</a>
#
# With over \$300 million revenue a year, Kayak operates in almost all countries and all languages to help their users book travels accros the globe.

# %% [markdown]
# ## Project 🚧
#
# The marketing team needs help on a new project. After doing some user research, the team discovered that **70% of their users who are planning a trip would like to have more information about the destination they are going to**.
#
# In addition, user research shows that **people tend to be defiant about the information they are reading if they don't know the brand** which produced the content.
#
# Therefore, Kayak Marketing Team would like to create an application that will recommend where people should plan their next holidays. The application should be based on real data about:
#
# * Weather
# * Hotels in the area
#
# The application should then be able to recommend the best destinations and hotels based on the above variables at any given time.

# %% [markdown]
# ## Goals 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * Scrape data from destinations
# * Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse

# %% [markdown]
# ## Scope of this project 🖼️
#
# Marketing team wants to focus first on the best cities to travel to in France. According <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> here are the top-35 cities to visit in France:
#
# ```python
# ["Mont Saint Michel",
# "St Malo",
# "Bayeux",
# "Le Havre",
# "Rouen",
# "Paris",
# "Amiens",
# "Lille",
# "Strasbourg",
# "Chateau du Haut Koenigsbourg",
# "Colmar",
# "Eguisheim",
# "Besancon",
# "Dijon",
# "Annecy",
# "Grenoble",
# "Lyon",
# "Gorges du Verdon",
# "Bormes les Mimosas",
# "Cassis",
# "Marseille",
# "Aix en Provence",
# "Avignon",
# "Uzes",
# "Nimes",
# "Aigues Mortes",
# "Saintes Maries de la mer",
# "Collioure",
# "Carcassonne",
# "Ariege",
# "Toulouse",
# "Montauban",
# "Biarritz",
# "Bayonne",
# "La Rochelle"]
# ```
#
# Your team should focus **only on the above cities for your project**.

# %% [markdown]
# ## Helpers 🦮
#
# To help you achieve this project, here are a few tips that should help you
#
# ### Get weather data with an API
#
# *   Use https://nominatim.org/ to get the gps coordinates of all the cities (no subscription required) Documentation : https://nominatim.org/release-docs/develop/api/Search/
#
# *   Use https://openweathermap.org/appid (you have to subscribe to get a free apikey) and https://openweathermap.org/api/one-call-api to get some information about the weather for the 35 cities and put it in a DataFrame
#
# *   Determine the list of cities where the weather will be the nicest within the next 7 days For example, you can use the values of daily.pop and daily.rain to compute the expected volume of rain within the next 7 days... But it's only an example, actually you can have different opinions on a what a nice weather would be like 😎 Maybe the most important criterion for you is the temperature or humidity, so feel free to change the rules !
#
# *   Save all the results in a `.csv` file, you will use it later 😉 You can save all the informations that seem important to you ! Don't forget to save the name of the cities, and also to create a column containing a unique identifier (id) of each city (this is important for what's next in the project)
#
# *   Use plotly to display the best destinations on a map
#
# ### Scrape Booking.com
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information asyou want, but we suggest that you get at least:
#
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel
#
#
# ### Create your data lake using S3
#
# Once you managed to build your dataset, you should store into S3 as a csv file.
#
# ### ETL
#
# Once you uploaded your data onto S3, it will be better for the next data analysis team to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, extract your data from S3 and store it in your newly created DB.

# %% [markdown]
# ## Deliverable 📬
#
# To complete this project, your team should deliver:
#
# * A `.csv` file in an S3 bucket containing enriched information about weather and hotels for each french city
#
# * A SQL Database where we should be able to get the same cleaned data from S3
#
# * Two maps where you should have a Top-5 destinations and a Top-20 hotels in the area. You can use plotly or any other library to do so. It should look something like this:
#
# ![Map](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/Kayak_best_destination_project.png)

# %% [markdown]
# # RÉCUPÉRATION DES COORDONNÉES GPS POUR CHAQUE VILLE
# SOURCE : https://nominatim.openstreetmap.org

# %%
import requests
import pandas as pd
import json

# %%
# LISTE DES VILLES 35 TOP CITIES
villes = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
ville_test = 'Lyon'
nomi_params = {'city': ville_test, 'country': 'fr', 'format': 'json'}

r = requests.get('https://nominatim.openstreetmap.org/search?', params=nomi_params)
# Out:
# 2

# %%
r.json()
# Out:
# []

# %%
results_json = r.json()
df = pd.DataFrame.from_dict(results_json)
df
# Out:
#     place_id                                            licence  osm_type  \
# 0  298358151  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1  298312296  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#     osm_id                                     boundingbox         lat  \
# 0   120965  [45.7073666, 45.8082628, 4.7718134, 4.8983774]  45.7578137
# 1  1663048   [45.454026, 45.9393015, 4.3480714, 5.1603205]  45.6963425
#
#                  lon                                       display_name  \
# 0          4.8320114  Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône...
# 1  4.735948029916814  Lyon, Rhône, Auvergne-Rhône-Alpes, France métr...
#
#       class            type  importance  \
# 0  boundary  administrative    0.901378
# 1  boundary  administrative    0.578804
#
#                                                 icon
# 0  https://nominatim.openstreetmap.org/ui/mapicon...
# 1  https://nominatim.openstreetmap.org/ui/mapicon...

# %%
df['lon'][0]
# Out:
# '4.8320114'

# %%
r.json()
# Out:
# [{'place_id': 298358151,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 120965,
#   'boundingbox': ['45.7073666', '45.8082628', '4.7718134', '4.8983774'],
#   'lat': '45.7578137',
#   'lon': '4.8320114',
#   'display_name': 'Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9013775965432667,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298312296,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1663048,
#   'boundingbox': ['45.454026', '45.9393015', '4.3480714', '5.1603205'],
#   'lat': '45.6963425',
#   'lon': '4.735948029916814',
#   'display_name': 'Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5788043506708112,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]

# %%
results_json = r.json()
df = pd.DataFrame.from_dict(results_json)
df
# Out:
#     place_id                                            licence  osm_type  \
# 0  298358151  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1  298312296  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#     osm_id                                     boundingbox         lat  \
# 0   120965  [45.7073666, 45.8082628, 4.7718134, 4.8983774]  45.7578137
# 1  1663048   [45.454026, 45.9393015, 4.3480714, 5.1603205]  45.6963425
#
#                  lon                                       display_name  \
# 0          4.8320114  Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône...
# 1  4.735948029916814  Lyon, Rhône, Auvergne-Rhône-Alpes, France métr...
#
#       class            type  importance  \
# 0  boundary  administrative    0.901378
# 1  boundary  administrative    0.578804
#
#                                                 icon
# 0  https://nominatim.openstreetmap.org/ui/mapicon...
# 1  https://nominatim.openstreetmap.org/ui/mapicon...

# %%
#gps.describe()

# %%
# gps = pd.DataFrame(columns=['ville', 'alias', 'latitude', 'longitude']) # Création des colonnes avec alias
gps = pd.DataFrame(columns=['ville','latitude','longitude']) # Création des colonnes sans alias

for ville in villes:
  print("Début des requêtes sur chaque ville")
  nomi_params = {'city': ville, 'country': 'fr', 'format': 'json'}
  r = requests.get('https://nominatim.openstreetmap.org/search?', params=nomi_params)
  if (len(r.json()) == 0):
    nomi_params = {'query': ville, 'country': 'fr', 'format': 'json'}
    r = requests.get('https://nominatim.openstreetmap.org/search?', params=nomi_params)

  results_json = r.json()
  df = pd.DataFrame.from_dict(results_json)

  # Création des mes valeurs
  #ville_alias = df['display_name'][0].split(',')[0]
  ville = ville
  lat = df['lat'][0]
  lon = df['lon'][0]

  #print(ville)
  #print(ville_alias)
  #print(lat)
  #print(lon)
  #gps= pd.DataFrame

  data_gps = {'ville' : ville, 'latitude' : lat, 'longitude' : lon}
  actual_gps = pd.DataFrame([data_gps])

  #display(actual_gps)
  print(r.json())
  gps = pd.concat([gps, actual_gps], ignore_index=True, axis=0)

print("Fin des requêtes sur chaque ville")
display(gps)
# Out:
# =============
# [{'place_id': 156604934, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 211285890, 'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'], 'lat': '48.6359541', 'lon': '-1.511459954959514', 'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France', 'class': 'place', 'type': 'islet', 'importance': 0.855436556781574}]
# =============
# [{'place_id': 298187446, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 905534, 'boundingbox': ['48.5979853', '48.6949736', '-2.0765246', '-1.9367259'], 'lat': '48.649518', 'lon': '-2.0260409', 'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7764672172428952, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298319921, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1653637, 'boundingbox': ['48.266957', '48.7220079', '-2.1619838', '-1.4850797'], 'lat': '48.4904728', 'lon': '-1.7421554637978962', 'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6572742271829002, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 338788269, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9917850021, 'boundingbox': ['47.5783644', '47.5983644', '0.91302', '0.93302'], 'lat': '47.5883644', 'lon': '0.92302', 'display_name': 'Saint-Malo, Bec-Sec, Auzouer-en-Touraine, Loches, Indre-et-Loire, Centre-Val de Loire, France métropolitaine, 37110, France', 'class': 'place', 'type': 'neighbourhood', 'importance': 0.45000999999999997}, {'place_id': 6048349, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 739408809, 'boundingbox': ['47.7893339', '47.8293339', '-1.5497978', '-1.5097978'], 'lat': '47.8093339', 'lon': '-1.5297978', 'display_name': 'Saint-Malo, Teillay, Redon, Ille-et-Vilaine, Bretagne, France métropolitaine, 35620, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.45, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 49547994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4381382983, 'boundingbox': ['47.9180971', '47.9580971', '-2.4312551', '-2.3912551'], 'lat': '47.9380971', 'lon': '-2.4112551', 'display_name': 'Saint-Malo, Ploërmel, Pontivy, Morbihan, Bretagne, France métropolitaine, 56800, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.45, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 50172493, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4419648415, 'boundingbox': ['47.9559266', '47.9959266', '-2.3969864', '-2.3569864'], 'lat': '47.9759266', 'lon': '-2.3769864', 'display_name': 'Saint-Malo, Loyat, Pontivy, Morbihan, Bretagne, France métropolitaine, 56800, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.45, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 49747496, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4346569622, 'boundingbox': ['47.5168163', '47.5568163', '-2.1739705', '-2.1339705'], 'lat': '47.5368163', 'lon': '-2.1539705', 'display_name': 'Saint-Malo, Saint-Dolay, Vannes, Morbihan, Bretagne, France métropolitaine, 56130, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.45, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 342419537, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10009043996, 'boundingbox': ['47.2817513', '47.3217513', '0.7806012', '0.8206012'], 'lat': '47.3017513', 'lon': '0.8006012', 'display_name': 'Saint-Malo, Esvres, Arrondissement de Tours, Indre-et-Loire, Centre-Val de Loire, France métropolit ...
# =============
# [{'place_id': 298563984, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 145776, 'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378'], 'lat': '49.2764624', 'lon': '-0.7024738', 'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7827003853621928, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298371637, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1656892, 'boundingbox': ['49.0931773', '49.3978952', '-1.1412392', '-0.4113237'], 'lat': '49.2455634', 'lon': '-0.7916770441791112', 'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5869371059968022, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297969319, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 104492, 'boundingbox': ['49.4516697', '49.5401463', '0.0667992', '0.1955556'], 'lat': '49.4938975', 'lon': '0.1079732', 'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.9223325741883645, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298735809, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3012370, 'boundingbox': ['49.4287837', '49.826254', '0.0657702', '0.6917633'], 'lat': '49.627549200000004', 'lon': '0.3921241327294534', 'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6752824455605189, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 46354396, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3918888890, 'boundingbox': ['48.1371505', '48.1771505', '-1.7514713', '-1.7114713'], 'lat': '48.1571505', 'lon': '-1.7314713', 'display_name': 'Le Havre, Montgermont, Rennes, Ille-et-Vilaine, Bretagne, France métropolitaine, 35760, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55001, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 96283622, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9445672954, 'boundingbox': ['49.1480287', '49.1880287', '-0.2284173', '-0.1884173'], 'lat': '49.1680287', 'lon': '-0.2084173', 'display_name': 'Le Havre, Banneville-la-Campagne, Caen, Calvados, Normandie, France métropolitaine, 14940, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 35418385, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2934385149, 'boundingbox': ['48.5361794', '48.5761794', '-1.9047792', '-1.8647792'], 'lat': '48.5561794', 'lon': '-1.8847792', 'display_name': 'Le Havre, Miniac-Morvan, Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35540, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 24980084, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2696215787, 'boundingbox': ['48.4308301', '48.4309301', '-2.5484416', '-2.5483416'], 'lat': '48.4308801', 'lon': '-2.5483916', 'display_name': "Le Havre, Landéhen, Saint-Brieuc, Côtes-d'Armor, Bretagne, France métropolitaine, 22400, France", 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.5}]
# =============
# [{'place_id': 297988461, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 75628, 'boundingbox': ['49.4172001', '49.4652601', '1.0300648', '1.1521157'], 'lat': '49.4404591', 'lon': '1.0939658', 'display_name': 'Rouen, Seine-Maritime, Normandie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8500726280583955, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298523752, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3018659, 'boundingbox': ['49.2506708', '49.7851695', '0.6000692', '1.4521223'], 'lat': '49.518435', 'lon': '1.0221643441483266', 'display_name': 'Rouen, Seine-Maritime, Normandie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6037423679622278, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 16441407, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1829586795, 'boundingbox': ['48.0531019', '48.0931019', '-1.0567267', '-1.0167267'], 'lat': '48.0731019', 'lon': '-1.0367267', 'display_name': 'Rouen, Bréal-sous-Vitré, Fougères-Vitré, Ille-et-Vilaine, Bretagne, France métropolitaine, 35370, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46001, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 21427646, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2409955196, 'boundingbox': ['47.8236948', '47.8237948', '0.3917512', '0.3918512'], 'lat': '47.8237448', 'lon': '0.3918012', 'display_name': "Rouen, Pruillé-l'Éguillé, La Flèche, Sarthe, Pays de la Loire, France métropolitaine, 72150, France", 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 40772987, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3251138350, 'boundingbox': ['44.4687708', '44.4688708', '1.7191343', '1.7192343'], 'lat': '44.4688208', 'lon': '1.7191843', 'display_name': 'Rouen, Saint-Martin-Labouval, Cahors, Lot, Occitanie, France métropolitaine, 46330, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}]
# =============
# [{'place_id': 297919168, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7444, 'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'], 'lat': '48.8534951', 'lon': '2.3483915', 'display_name': 'Paris, Quartier Les Îles, Paris, Île-de-France, France métropolitaine, 75004, France', 'class': 'boundary', 'type': 'administrative', 'importance': 1.0417101715588672, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298308224, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1641193, 'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'], 'lat': '48.8588897', 'lon': '2.3200410217200766', 'display_name': 'Paris, Quartier des Invalides, Paris, Île-de-France, France métropolitaine, 75007, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6383953917728152, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 14824260, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1610803906, 'boundingbox': ['44.6170913', '44.6570913', '0.75482', '0.79482'], 'lat': '44.6370913', 'lon': '0.77482', 'display_name': 'Parisot, Villeréal, Villeneuve-sur-Lot, Lot-et-Garonne, Nouvelle-Aquitaine, France métropolitaine, 47210, France', 'class': 'place', 'type': 'village', 'importance': 0.47500000000000003, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 77071395, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7346812249, 'boundingbox': ['44.5426798', '44.5826798', '-0.885783', '-0.845783'], 'lat': '44.5626798', 'lon': '-0.865783', 'display_name': 'Paris, Salles, Arcachon, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33770, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 49811624, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4390555851, 'boundingbox': ['44.471379', '44.511379', '0.3740874', '0.4140874'], 'lat': '44.491379', 'lon': '0.3940874', 'display_name': 'Paris, Labretonie, Marmande, Lot-et-Garonne, Nouvelle-Aquitaine, France métropolitaine, 47350, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 57209078, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5204281064, 'boundingbox': ['43.8087799', '43.8487799', '5.4070482', '5.4470482'], 'lat': '43.8287799', 'lon': '5.4270482', 'display_name': "Paris, Sivergues, Apt, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, 84400, France", 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 360456764, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10766865813, 'boundingbox': ['43.6676246', '43.6677246', '-0.1117883', '-0.1116883'], 'lat': '43.6676746', 'lon': '-0.1117383', 'display_name': 'Paris, Tarsac, Mirande, Gers, Occitanie, France métropolitaine, 32400, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41000999999999993}, {'place_id': 351896893, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10291696157, 'boundingbox': ['44.0011508', '44.0012508', '-0.3731409', '-0.3730409'], 'lat': '44.0012008', 'lon': '-0.3730909', 'display_name': 'Paris, Pouydesseaux, Mont-de-Marsan, Landes, Nouvelle-Aquitain ...
# =============
# [{'place_id': 297990795, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 114347, 'boundingbox': ['49.846837', '49.9505487', '2.2235574', '2.3457767'], 'lat': '49.8941708', 'lon': '2.2956951', 'display_name': 'Amiens, Somme, Hauts-de-France, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.834948962224904, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298551968, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3257541, 'boundingbox': ['49.683118', '50.2390386', '1.6355161', '2.6799559'], 'lat': '49.9610783', 'lon': '2.2518180697364363', 'display_name': 'Amiens, Somme, Hauts-de-France, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6171003594381197, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297939921, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 58404, 'boundingbox': ['50.6008264', '50.6612596', '2.9679677', '3.125725'], 'lat': '50.6365654', 'lon': '3.0635282', 'display_name': 'Lille, Nord, Hauts-de-France, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8632037863087654, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298308062, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1643919, 'boundingbox': ['50.4416259', '50.7946088', '2.789132', '3.3291133'], 'lat': '50.61806395', 'lon': '3.045303691127442', 'display_name': 'Lille, Nord, Hauts-de-France, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5905052507959779, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 299345550, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9402509, 'boundingbox': ['50.6008264', '50.6571564', '3.0168437', '3.1040272'], 'lat': '50.6290997', 'lon': '3.0597072679624127', 'display_name': 'Lille, Nord, Hauts-de-France, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.51, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 73990004, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7006486544, 'boundingbox': ['46.7218347', '46.7618347', '0.2855063', '0.3255063'], 'lat': '46.7418347', 'lon': '0.3055063', 'display_name': 'Lille, Vendeuvre-du-Poitou, Saint-Martin-la-Pallu, Poitiers, Vienne, Nouvelle-Aquitaine, France métropolitaine, 86380, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 40799677, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3282379739, 'boundingbox': ['44.1471697', '44.1871697', '2.010224', '2.050224'], 'lat': '44.1671697', 'lon': '2.030224', 'display_name': 'Lille, Saint-Christophe, Albi, Tarn, Occitanie, France métropolitaine, 81190, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 71332074, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6709848146, 'boundingbox': ['43.7614469', '43.7615469', '-0.1705688', '-0.1704688'], 'lat': '43.7614969', 'lon': '-0.1705188', 'display_name': 'Lille, Le Houga, Condom, Gers, Occitanie, France métropolitaine, 32460, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}]
# =============
# [{'place_id': 297970735, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 71033, 'boundingbox': ['48.491861', '48.6461896', '7.6881371', '7.8360646'], 'lat': '48.584614', 'lon': '7.7507127', 'display_name': 'Strasbourg, Bas-Rhin, Grand Est, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8848054279118731, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298926836, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4630050, 'boundingbox': ['48.4339379', '48.7022939', '7.5377795', '7.8957138'], 'lat': '48.5681009', 'lon': '7.688597194984311', 'display_name': 'Strasbourg, Bas-Rhin, Grand Est, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6466178720918443, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 48803773, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4245068168, 'boundingbox': ['48.2494726', '48.2495726', '7.3454423', '7.3455423'], 'lat': '48.2495226', 'lon': '7.3454923', 'display_name': 'Château du Haut-Kœnigsbourg, Orschwiller, Sélestat-Erstein, Bas-Rhin, Grand Est, France métropolitaine, 67600, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.5}]
# =============
# [{'place_id': 297941135, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 61423, 'boundingbox': ['48.0407053', '48.182062', '7.3154803', '7.469167'], 'lat': '48.0777517', 'lon': '7.3579641', 'display_name': 'Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6809087464752241, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297958707, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 79442, 'boundingbox': ['48.0240327', '48.0515072', '7.2412792', '7.351854'], 'lat': '48.0447968', 'lon': '7.3079618', 'display_name': 'Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68420, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7349720206561967, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297963471, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 103599, 'boundingbox': ['47.2006872', '47.3200746', '5.9409668', '6.0835059'], 'lat': '47.2380222', 'lon': '6.0243622', 'display_name': 'Besançon, Doubs, Bourgogne-Franche-Comté, France métropolitaine, 25000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7183511874833898, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298313974, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1682291, 'boundingbox': ['46.9342078', '47.5224481', '5.6987633', '6.5005111'], 'lat': '47.228367899999995', 'lon': '6.01892310902501', 'display_name': 'Besançon, Doubs, Bourgogne-Franche-Comté, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.4985240140444952, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297949589, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 74090, 'boundingbox': ['47.2862467', '47.3774741', '4.9624434', '5.1020598'], 'lat': '47.3215806', 'lon': '5.0414701', 'display_name': "Dijon, Côte-d'Or, Bourgogne-Franche-Comté, France métropolitaine, 21000, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.8436193867801005, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298315430, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1685958, 'boundingbox': ['47.1075054', '47.7099499', '4.568715', '5.5188651'], 'lat': '47.4087504', 'lon': '5.064635891748798', 'display_name': "Dijon, Côte-d'Or, Bourgogne-Franche-Comté, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.6019557965128309, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 72526646, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6926615059, 'boundingbox': ['48.2816882', '48.3016882', '6.9658892', '6.9858892'], 'lat': '48.2916882', 'lon': '6.9758892', 'display_name': 'Dijon, Saint-Dié-des-Vosges, Vosges, Grand Est, France métropolitaine, 88100, France', 'class': 'place', 'type': 'neighbourhood', 'importance': 0.46001}, {'place_id': 120076, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 27278197, 'boundingbox': ['45.277992', '45.317992', '2.4928431', '2.5328431'], 'lat': '45.297992', 'lon': '2.5128431', 'display_name': 'Dijon, Le Monteil, Mauriac, Cantal, Auvergne-Rhône-Alpes, France métropolitaine, 15240, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 20046163, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2301564527, 'boundingbox': ['46.7597435', '46.7598435', '4.6920503', '4.6921503'], 'lat': '46.7597935', 'lon': '4.6921003', 'display_name': 'Dijon, Moroges, Chalon-sur-Saône, Saône-et-Loire, Bourgogne-Franche-Comté, France métropolitaine, 71390, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 35578059, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2948477963, 'boundingbox': ['44.0664553', '44.0665553', '0.4022766', '0.4023766'], 'lat': '44.0665053', 'lon': '0.4023266', 'display_name': 'Dijon, Francescas, Nérac, Lot-et-Garonne, Nouvelle-Aquitaine, France métropolitaine, 47600, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}]
# =============
# [{'place_id': 298996776, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6791758, 'boundingbox': ['45.8280024', '45.9766928', '6.0484121', '6.2043932'], 'lat': '45.8992348', 'lon': '6.1288847', 'display_name': 'Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7890769115704566, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298314237, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1668737, 'boundingbox': ['45.6817078', '46.0702526', '5.8624243', '6.5559605'], 'lat': '45.8782687', 'lon': '6.169945398631612', 'display_name': 'Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5498058423953756, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298340614, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 102480, 'boundingbox': ['45.8492306', '45.9303296', '6.1010113', '6.155931'], 'lat': '45.88975045', 'lon': '6.135465100225999', 'display_name': 'Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, 74000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.36315075904307603, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297959613, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 80348, 'boundingbox': ['45.1541442', '45.2140762', '5.6776059', '5.7531315'], 'lat': '45.1875602', 'lon': '5.7357819', 'display_name': 'Grenoble, Isère, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8518085495723451, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298317332, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1676230, 'boundingbox': ['44.6958924', '45.4923349', '5.1346493', '6.3590884'], 'lat': '45.0940786', 'lon': '5.697197979937964', 'display_name': 'Grenoble, Isère, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6110591387973789, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 50603806, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4498229727, 'boundingbox': ['46.7797256', '46.7997256', '-0.9193616', '-0.8993616'], 'lat': '46.7897256', 'lon': '-0.9093616', 'display_name': 'Grenoble, Le Boupère, Fontenay-le-Comte, Vendée, Pays de la Loire, France métropolitaine, 85510, France', 'class': 'place', 'type': 'farm', 'importance': 0.41}]
# =============
# [{'place_id': 298358151, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 120965, 'boundingbox': ['45.7073666', '45.8082628', '4.7718134', '4.8983774'], 'lat': '45.7578137', 'lon': '4.8320114', 'display_name': 'Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.9013775965432667, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298312296, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1663048, 'boundingbox': ['45.454026', '45.9393015', '4.3480714', '5.1603205'], 'lat': '45.6963425', 'lon': '4.735948029916814', 'display_name': 'Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5788043506708112, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# True
# =============
# [{'place_id': 298464367, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2202162, 'boundingbox': ['-50.2187169', '51.3055721', '-178.3873749', '172.3057152'], 'lat': '46.603354', 'lon': '1.8883335', 'display_name': 'France', 'class': 'boundary', 'type': 'administrative', 'importance': 1.0133264437396503, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 298218593, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1118915, 'boundingbox': ['43.0864271', '43.2278201', '6.2716142', '6.4514893'], 'lat': '43.1506968', 'lon': '6.3419285', 'display_name': "Bormes-les-Mimosas, Toulon, Var, Provence-Alpes-Côte d'Azur, France métropolitaine, 83230, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.8773164194582208, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297951775, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 76425, 'boundingbox': ['43.1884732', '43.2487231', '5.5063193', '5.5945199'], 'lat': '43.2140359', 'lon': '5.5396318', 'display_name': "Cassis, Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13260, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.6867802490530643, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 298048987, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 76469, 'boundingbox': ['43.1696228', '43.3910329', '5.2286312', '5.5324758'], 'lat': '43.2961743', 'lon': '5.3699525', 'display_name': "Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13000, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.8913768937556641, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298543915, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1686370, 'boundingbox': ['43.1573984', '43.4427166', '5.2286312', '5.7628627'], 'lat': '43.301487800000004', 'lon': '5.548001012099657', 'display_name': "Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.5243170044259858, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 49696804, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4366530098, 'boundingbox': ['44.4176097', '44.4576097', '0.9156249', '0.9556249'], 'lat': '44.4376097', 'lon': '0.9356249', 'display_name': 'Marseille, Saint-Georges, Villeneuve-sur-Lot, Lot-et-Garonne, Nouvelle-Aquitaine, France métropolitaine, 47370, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 19052924, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2177465260, 'boundingbox': ['42.9532743', '42.9533743', '2.4530426', '2.4531426'], 'lat': '42.9533243', 'lon': '2.4530926', 'display_name': 'Marseille, Albières, Narbonne, Aude, Occitanie, France métropolitaine, 11330, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41000999999999993}, {'place_id': 352460503, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10302914125, 'boundingbox': ['43.8479129', '43.8480129', '-0.2095583', '-0.2094583'], 'lat': '43.8479629', 'lon': '-0.2095083', 'display_name': 'Marseille, Bourdalat, Mont-de-Marsan, Landes, Nouvelle-Aquitaine, France métropolitaine, 40190, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41000999999999993}, {'place_id': 352940082, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4530798817, 'boundingbox': ['43.6239348', '43.6240348', '1.8840826', '1.8841826'], 'lat': '43.6239848', 'lon': '1.8841326', 'display_name': 'Marseille, Roquevidal, Castres, Tarn, Occitanie, France métropolitaine, 81470, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41000999999999993}, {'place_id': 52850630, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4665702595, 'boundingbox': ['43.3365018', '43.3366018', '1.6533168', '1.6534168'], 'lat': '43.3365518', 'lon': '1.6533668', 'display_name': 'Marseille, Montgeard, Toulouse, Haute-Garonne, Occitanie, France métropolitaine, 31560, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 39838456, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3153377765, 'boundingbox': ['48.3005145', '48.3006145', '-2.7575464', '-2.7574464'], 'lat': '48.3005645', 'lon': '-2.7574964', 'display_name': "Marseille, Gausson, Saint-Brieuc, Côtes-d'Armor, Bretagne, France métropolitaine, 22150, France", 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 49656865, 'licence': 'Data © OpenStreetMap contributors, ODbL  ...
# =============
# [{'place_id': 298018423, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 70279, 'boundingbox': ['43.4461058', '43.6259224', '5.2694745', '5.5063013'], 'lat': '43.5298424', 'lon': '5.4474738', 'display_name': "Aix-en-Provence, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.991084766383758, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298550737, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1686391, 'boundingbox': ['43.3681732', '43.7721131', '4.9534171', '5.8135205'], 'lat': '43.570984749999994', 'lon': '5.382418891915822', 'display_name': "Aix-en-Provence, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.731575982276377, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297965181, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 102478, 'boundingbox': ['43.8866543', '43.9967419', '4.7396309', '4.9271468'], 'lat': '43.9492493', 'lon': '4.8059012', 'display_name': "Avignon, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.8320935210501683, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 347283476, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1693195, 'boundingbox': ['43.8504637', '44.1181923', '4.7396309', '5.1599743'], 'lat': '43.98456915', 'lon': '4.885811932798079', 'display_name': "Avignon, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, France", 'class': 'boundary', 'type': 'administrative', 'importance': 0.6100099999999999, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 65724476, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6098960124, 'boundingbox': ['48.3712703', '48.4112703', '-1.7781987', '-1.7381987'], 'lat': '48.3912703', 'lon': '-1.7581987', 'display_name': 'Avignon, Combourg, Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35270, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 16864168, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1875807654, 'boundingbox': ['46.666008', '46.706008', '1.0796784', '1.1196784'], 'lat': '46.686008', 'lon': '1.0996784', 'display_name': 'Avignon, Douadic, Le Blanc, Indre, Centre-Val de Loire, France métropolitaine, 36300, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 359168136, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 10728501773, 'boundingbox': ['46.2381606', '46.2382606', '4.2375184', '4.2376184'], 'lat': '46.2382106', 'lon': '4.2375684', 'display_name': 'Avignon, Saint-Maurice-lès-Châteauneuf, Charolles, Saône-et-Loire, Bourgogne-Franche-Comté, France métropolitaine, 71740, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41000999999999993}, {'place_id': 37742722, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3080754645, 'boundingbox': ['43.7962412', '43.7963412', '1.8177775', '1.8178775'], 'lat': '43.7962912', 'lon': '1.8178275', 'display_name': 'Avignon, Parisot, Albi, Tarn, Occitanie, France métropolitaine, 81310, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}]
# =============
# [{'place_id': 298413899, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 380050, 'boundingbox': ['43.9811093', '44.0765914', '4.3852299', '4.4467859'], 'lat': '44.0121279', 'lon': '4.4196718', 'display_name': 'Uzès, Nîmes, Gard, Occitanie, France métropolitaine, 30700, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6375332788749554, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 298643421, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 378685, 'boundingbox': ['43.7412659', '43.9230177', '4.2356708', '4.4496605'], 'lat': '43.8374249', 'lon': '4.3600687', 'display_name': 'Nîmes, Gard, Occitanie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7030547856893241, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298482920, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2757959, 'boundingbox': ['43.460197', '44.3443155', '4.0009632', '4.8455335'], 'lat': '43.9023189', 'lon': '4.390525733141193', 'display_name': 'Nîmes, Gard, Occitanie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.47472087083815584, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 298067298, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 272287, 'boundingbox': ['43.4958113', '43.5920372', '4.0760703', '4.2442867'], 'lat': '43.5658225', 'lon': '4.1912837', 'display_name': 'Aigues-Mortes, Nîmes, Gard, Occitanie, France métropolitaine, 30220, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8323802893018254, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 56982125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5196911673, 'boundingbox': ['45.3114132', '45.3514132', '1.01014', '1.05014'], 'lat': '45.3314132', 'lon': '1.03014', 'display_name': "Aigues Mortes, Saint-Martial-d'Albarède, Nontron, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24160, France", 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}]
# =============
# [{'place_id': 298133731, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 414459, 'boundingbox': ['43.4062445', '43.5858463', '4.2301364', '4.6444785'], 'lat': '43.4522771', 'lon': '4.4287172', 'display_name': "Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13460, France", 'class': 'boundary', 'type': 'administrative', 'importance': 1.0725165122764473, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297903903, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 18409, 'boundingbox': ['42.4832453', '42.5341084', '3.0495074', '3.0994238'], 'lat': '42.52505', 'lon': '3.0831554', 'display_name': 'Collioure, Céret, Pyrénées-Orientales, Occitanie, France métropolitaine, 66190, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7184088842062248, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 297995754, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 37774, 'boundingbox': ['43.1713069', '43.2443707', '2.2615684', '2.4362676'], 'lat': '43.2130358', 'lon': '2.3491069', 'display_name': 'Carcassonne, Aude, Occitanie, France métropolitaine, 11000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7991672924570599, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298482493, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2753432, 'boundingbox': ['43.0311477', '43.4600382', '1.6887151', '2.7118623'], 'lat': '43.24558525', 'lon': '2.191051094614102', 'display_name': 'Carcassonne, Aude, Occitanie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5863904735942329, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 54271385, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4762487194, 'boundingbox': ['44.9345094', '44.9745094', '1.0196609', '1.0596609'], 'lat': '44.9545094', 'lon': '1.0396609', 'display_name': 'Carcassonne, Tursac, Sarlat-la-Canéda, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24620, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}]
# True
# =============
# [{'place_id': 298464367, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2202162, 'boundingbox': ['-50.2187169', '51.3055721', '-178.3873749', '172.3057152'], 'lat': '46.603354', 'lon': '1.8883335', 'display_name': 'France', 'class': 'boundary', 'type': 'administrative', 'importance': 1.0133264437396503, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# ...
# =============
# [{'place_id': 298355626, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 137735, 'boundingbox': ['43.9512579', '44.0922122', '1.2865419', '1.4427914'], 'lat': '44.0175835', 'lon': '1.3549991', 'display_name': 'Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, 82000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7642482145338698, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298265867, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1389237, 'boundingbox': ['42.7802097', '42.801254', '0.5994724', '0.6523087'], 'lat': '42.7917916', 'lon': '0.6081298', 'display_name': 'Montauban-de-Luchon, Saint-Gaudens, Haute-Garonne, Occitanie, France métropolitaine, 31110, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7453725568292895, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298543897, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1646846, 'boundingbox': ['43.7674288', '44.3406002', '1.0578543', '2.0008951'], 'lat': '44.0541438', 'lon': '1.4937961569159295', 'display_name': 'Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5485505566535597, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 4977505, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 599730587, 'boundingbox': ['16.1949851', '16.2349851', '-61.5219724', '-61.4819724'], 'lat': '16.2149851', 'lon': '-61.5019724', 'display_name': 'Montauban, Le Gosier, Pointe-à-Pitre, Guadeloupe, 97190, France', 'class': 'place', 'type': 'suburb', 'importance': 0.48500000000000004, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 55295278, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4931595563, 'boundingbox': ['45.0764341', '45.1164341', '0.6875103', '0.7275103'], 'lat': '45.0964341', 'lon': '0.7075103', 'display_name': 'Montauban, Notre-Dame-de-Sanilhac, Sanilhac, Périgueux, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24660, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 53358319, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4735046835, 'boundingbox': ['44.9707069', '45.0107069', '0.5935096', '0.6335096'], 'lat': '44.9907069', 'lon': '0.6135096', 'display_name': 'Montauban, Beauregard-et-Bassac, Périgueux, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24140, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 52357308, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4623349457, 'boundingbox': ['44.7646241', '44.8046241', '1.0311889', '1.0711889'], 'lat': '44.7846241', 'lon': '1.0511889', 'display_name': 'Montauban, Carves, Sarlat-la-Canéda, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24170, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 52211930, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4575707817, 'boundingbox': ['48.0897629', '48.1297629', '-2.4737307', '-2.4337307'], 'lat': '48.1097629', 'lon ...
# =============
# [{'place_id': 298572327, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 166717, 'boundingbox': ['43.4475698', '43.4945381', '-1.5773906', '-1.5343915'], 'lat': '43.4832523', 'lon': '-1.5592776', 'display_name': 'Biarritz, Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64200, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.7896122503321825, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]
# =============
# [{'place_id': 298019575, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 166713, 'boundingbox': ['43.4498733', '43.5188846', '-1.5048438', '-1.417261'], 'lat': '43.4945144', 'lon': '-1.4736657', 'display_name': 'Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64100, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8127800210035323, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298484046, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2770753, 'boundingbox': ['43.0076101', '43.5474276', '-1.7910227', '-0.897372'], 'lat': '43.2775332', 'lon': '-1.2087111034758713', 'display_name': 'Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.5789594008138998, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 16583665, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1846698959, 'boundingbox': ['44.418205', '44.458205', '4.8683211', '4.9083211'], 'lat': '44.438205', 'lon': '4.8883211', 'display_name': 'Bayonne, Grignan, Nyons, Drôme, Auvergne-Rhône-Alpes, France métropolitaine, 26230, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 21112742, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2387259037, 'boundingbox': ['43.8709989', '43.9109989', '2.0901285', '2.1301285'], 'lat': '43.8909989', 'lon': '2.1101285', 'display_name': 'Bayonne, Carlus, Albi, Tarn, Occitanie, France métropolitaine, 81990, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 49586088, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4407040041, 'boundingbox': ['44.6219992', '44.6619992', '0.7385094', '0.7785094'], 'lat': '44.6419992', 'lon': '0.7585094', 'display_name': 'Bayonne, Parisot, Villeréal, Villeneuve-sur-Lot, Lot-et-Garonne, Nouvelle-Aquitaine, France métropolitaine, 47210, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.46, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 39828330, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3150806585, 'boundingbox': ['44.8268314', '44.8269314', '-0.3649808', '-0.3648808'], 'lat': '44.8268814', 'lon': '-0.3649308', 'display_name': 'Bayonne, Camarsac, Bordeaux, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33750, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 23167973, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2548829843, 'boundingbox': ['43.758875', '43.758975', '-0.4622593', '-0.4621593'], 'lat': '43.758925', 'lon': '-0.4622093', 'display_name': 'Bayonne, Montgaillard, Mont-de-Marsan, Landes, Nouvelle-Aquitaine, France métropolitaine, 40500, France', 'class': 'place', 'type': 'isolated_dwelling', 'importance': 0.41}, {'place_id': 74581652, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7086999964, 'boundingbox': ['44.1209381', '44.1210381', '-0.0151079', '-0.0150079'], 'lat': '44.1209881', 'lon': '-0.0150579', 'display_name': 'Bayonne, Lubbon, Mont-de-Marsan, Landes, Nouvelle-Aquitaine, France métropolitaine, 40240, France', 'class': 'place', 'type': 'isolated_dwelling', 'importa ...
# =============
# [{'place_id': 297987288, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 117858, 'boundingbox': ['46.1331804', '46.1908971', '-1.2419231', '-1.111097'], 'lat': '46.1591126', 'lon': '-1.1520434', 'display_name': 'La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17000, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.9014837096874572, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298233161, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1215878, 'boundingbox': ['47.7388479', '47.7647325', '5.7060641', '5.7454734'], 'lat': '47.7470598', 'lon': '5.7321403', 'display_name': 'La Rochelle, Vesoul, Haute-Saône, Bourgogne-Franche-Comté, France métropolitaine, 70120, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8332911295153212, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 298312040, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1661547, 'boundingbox': ['46.0036902', '46.3715027', '-1.5626797', '-0.6805266'], 'lat': '46.187679599999996', 'lon': '-1.064280735046797', 'display_name': 'La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, France', 'class': 'boundary', 'type': 'administrative', 'importance': 0.6230614454416834, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 21156293, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2385414528, 'boundingbox': ['48.4306156', '48.4706156', '-1.3607752', '-1.3207752'], 'lat': '48.4506156', 'lon': '-1.3407752', 'display_name': 'La Rochelle, La Selle-en-Coglès, Les Portes du Coglais, Fougères-Vitré, Ille-et-Vilaine, Bretagne, France métropolitaine, 35460, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 79114478, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7756578278, 'boundingbox': ['42.9397922', '42.9797922', '1.5615972', '1.6015972'], 'lat': '42.9597922', 'lon': '1.5815972', 'display_name': 'La Rochelle, Foix, Ariège, Occitanie, France métropolitaine, 09000, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 17964133, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2031899920, 'boundingbox': ['48.9231626', '48.9631626', '-1.3637098', '-1.3237098'], 'lat': '48.9431626', 'lon': '-1.3437098', 'display_name': 'La Rochelle, Saint-Denis-le-Gast, Coutances, Manche, Normandie, France métropolitaine, 50450, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 69952362, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6517919775, 'boundingbox': ['46.2462932', '46.2862932', '4.2703536', '4.3103536'], 'lat': '46.2662932', 'lon': '4.2903536', 'display_name': 'La Rochelle, La Chapelle-sous-Dun, Charolles, Saône-et-Loire, Bourgogne-Franche-Comté, France métropolitaine, 71800, France', 'class': 'place', 'type': 'hamlet', 'importance': 0.55, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_village.p.20.png'}, {'place_id': 57274748, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5205144194, 'boundingbox': ['48.5844837', '48.6244837 ...
#                            ville    latitude           longitude
# 0              Mont Saint Michel  48.6359541  -1.511459954959514
# 1                        St Malo   48.649518          -2.0260409
# 2                         Bayeux  49.2764624          -0.7024738
# 3                       Le Havre  49.4938975           0.1079732
# 4                          Rouen  49.4404591           1.0939658
# 5                          Paris  48.8534951           2.3483915
# 6                         Amiens  49.8941708           2.2956951
# 7                          Lille  50.6365654           3.0635282
# 8                     Strasbourg   48.584614           7.7507127
# 9   Chateau du Haut Koenigsbourg  48.2495226           7.3454923
# 10                        Colmar  48.0777517           7.3579641
# 11                     Eguisheim  48.0447968           7.3079618
# 12                      Besancon  47.2380222           6.0243622
# 13                         Dijon  47.3215806           5.0414701
# 14                        Annecy  45.8992348           6.1288847
# 15                      Grenoble  45.1875602           5.7357819
# 16                          Lyon  45.7578137           4.8320114
# 17              Gorges du Verdon   46.603354           1.8883335
# 18            Bormes les Mimosas  43.1506968           6.3419285
# 19                        Cassis  43.2140359           5.5396318
# 20                     Marseille  43.2961743           5.3699525
# 21               Aix en Provence  43.5298424           5.4474738
# 22                       Avignon  43.9492493           4.8059012
# 23                          Uzes  44.0121279           4.4196718
# 24                         Nimes  43.8374249           4.3600687
# 25                 Aigues Mortes  43.5658225           4.1912837
# 26      Saintes Maries de la mer  43.4522771           4.4287172
# 27                     Collioure    42.52505           3.0831554
# 28                   Carcassonne  43.2130358           2.3491069
# 29                        Ariege   46.603354           1.8883335
# 30                      Toulouse  43.6044622           1.4442469
# 31                     Montauban  44.0175835           1.3549991
# 32                      Biarritz  43.4832523          -1.5592776
# 33                       Bayonne  43.4945144          -1.4736657
# 34                   La Rochelle  46.1591126          -1.1520434

# %%
len(r.json())
# Out:
# 0

# %% [markdown]
# # RÉCUPÉRATION DES DONNÉES MÉTÉO
# SOURCE : https://openweathermap.org/api

# %%
# Abonnement One Call API 3.0 : 1000 appels gratuits par jour/  0,14€ /100 appels supplémentaires / Prévisions sur 8 jours
# API CALL EXEMPLE
# https://api.openweathermap.org/data/3.0/onecall?lat=33.44&lon=-94.04&exclude=current,minutely,hourly,alerts&appid={API key}

weather_params = {
    'lat': '48.6359541',
    'lon': '-1.511459954959514',
    'appid' : '94f4692bae2d84f1f7ffa0fcc3396021',
    'exclude' : 'current,minutely,hourly,alerts',
    'units' : 'metric',
    'lang': 'fr'
    }	
print("Début de la récupération des prévisions météo sur 8 jours")
r = requests.get('https://api.openweathermap.org/data/3.0/onecall?', params=weather_params)

if (r.status_code == 200):
  print("Fin de la récupération des données météo")
else:
  print("Une erreur s'est produite dans le traitement >> Erreur {r.status_code}")
# Out:
# Début de la récupération des prévisions météo sur 8 jours
# Fin de la récupération des données météo

# %%
# override encoding by real educated guess as provided by chardet
r.encoding = r.apparent_encoding
# access the data
results_weather_json= json.loads(r.text)

df_weather = pd.DataFrame.from_dict(results_weather_json)
df_weather

# Récupérer les data
# Out:
#       lat     lon      timezone  timezone_offset  \
# 0  48.636 -1.5115  Europe/Paris             7200
# 1  48.636 -1.5115  Europe/Paris             7200
# 2  48.636 -1.5115  Europe/Paris             7200
# 3  48.636 -1.5115  Europe/Paris             7200
# 4  48.636 -1.5115  Europe/Paris             7200
# 5  48.636 -1.5115  Europe/Paris             7200
# 6  48.636 -1.5115  Europe/Paris             7200
# 7  48.636 -1.5115  Europe/Paris             7200
#
#                                                daily
# 0  {'dt': 1681992000, 'sunrise': 1681967192, 'sun...
# 1  {'dt': 1682078400, 'sunrise': 1682053479, 'sun...
# 2  {'dt': 1682164800, 'sunrise': 1682139767, 'sun...
# 3  {'dt': 1682251200, 'sunrise': 1682226056, 'sun...
# 4  {'dt': 1682337600, 'sunrise': 1682312346, 'sun...
# 5  {'dt': 1682424000, 'sunrise': 1682398637, 'sun...
# 6  {'dt': 1682510400, 'sunrise': 1682484929, 'sun...
# 7  {'dt': 1682596800, 'sunrise': 1682571223, 'sun...
